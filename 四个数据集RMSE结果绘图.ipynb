# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
data1=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\度量指标\Aguado2009.xlsx')
data2=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\度量指标\Aria2015.xlsx')
data3=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\度量指标\Dikow2009.xlsx')
data4=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\度量指标\Griswold1999.xlsx')

# %%
data1
# Out:
#    method  Random  Median     EM    our
# 0    0.05   0.498   0.458  0.460  0.453
# 1    0.10   0.555   0.471    inf  0.463
# 2    0.20   0.651   0.494    inf  0.483
# 3    0.30   0.713   0.523    inf  0.498
# 4    0.40   0.796   0.559  0.552  0.520
# 5    0.50   0.856   0.584  0.588  0.560

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(15,10)) #如果不传入参数默认画板1
#fig = plt.figure() #如果不传入参数默认画板1
ax1=plt.subplot(2,2,1)   
data1['our'].plot(ax=ax1,linestyle=':',marker='o')
data1['Random'].plot(ax=ax1,linestyle='-')
data1['Median'].plot(ax=ax1,linestyle='dashed')
plt.legend()
ax1.set_title('Aguado2009')
plt.xlabel('缺失率')
plt.ylabel('RMSE')

ax2=plt.subplot(2,2,2)
data2['our'].plot(ax=ax2,linestyle=':',marker='o')
data2['Random'].plot(ax=ax2,linestyle='-')
data2['Median'].plot(ax=ax2,linestyle='dashed')
plt.legend()
ax2.set_title('Aria2015')
plt.xlabel('缺失率')
plt.ylabel('RMSE')

ax3=plt.subplot(2,2,3)   
data3['our'].plot(ax=ax3,linestyle=':',marker='o')
data3['Random'].plot(ax=ax3,linestyle='-')
data3['Median'].plot(ax=ax3,linestyle='dashed')
plt.legend()
ax3.set_title('Dikow2009')
plt.xlabel('缺失率')
plt.ylabel('RMSE')

ax4=plt.subplot(2,2,4)
data4['our'].plot(ax=ax4,linestyle=':',marker='o')
data4['Random'].plot(ax=ax4,linestyle='-')
data4['Median'].plot(ax=ax4,linestyle='dashed')
plt.legend()
ax4.set_title('Griswold1999')
plt.xlabel('缺失率')
plt.ylabel('RMSE')
#显示图像
plt.savefig('四个数据集缺失插补RMSE比较.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
