# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
data1=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\Aguado2009.xlsx',index_col = 'method').T
data2=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\Aria2015.xlsx',index_col = 'method').T
data3=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\Dikow2009.xlsx',index_col = 'method').T
data4=pd.read_excel(r'C:\Users\pro\Desktop\imptuedData2RF\05\Griswold1999.xlsx',index_col = 'method').T

# %%
data1
# Out:
# method  our  Random  Medain
# 0.05     58      80      56
# 0.10     78      82      78
# 0.20     94     110     112
# 0.30    122     120     116
# 0.40    108     138     130
# 0.50    118     138     132

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(15,10)) #如果不传入参数默认画板1
#fig = plt.figure() #如果不传入参数默认画板1
ax1=plt.subplot(2,2,1)   
data1['our'].plot(ax=ax1,linestyle=':',marker='o')
data1['Random'].plot(ax=ax1,linestyle='-')
data1['Medain'].plot(ax=ax1,linestyle='dashed')
plt.legend()
ax1.set_title('Aguado2009')
plt.xlabel('缺失率')
plt.ylabel('RF距离')

ax2=plt.subplot(2,2,2)
data1['our'].plot(ax=ax2,linestyle=':',marker='o')
data1['Random'].plot(ax=ax2,linestyle='-')
data1['Medain'].plot(ax=ax2,linestyle='dashed')
plt.legend()
ax2.set_title('Aria2015')
plt.xlabel('缺失率')
plt.ylabel('RF距离')

ax3=plt.subplot(2,2,3)   
data1['our'].plot(ax=ax3,linestyle=':',marker='o')
data1['Random'].plot(ax=ax3,linestyle='-')
data1['Medain'].plot(ax=ax3,linestyle='dashed')
plt.legend()
ax3.set_title('Dikow2009')
plt.xlabel('缺失率')
plt.ylabel('RF距离')

ax4=plt.subplot(2,2,4)
data1['our'].plot(ax=ax4,linestyle=':',marker='o')
data1['Random'].plot(ax=ax4,linestyle='-')
data1['Medain'].plot(ax=ax4,linestyle='dashed')
plt.legend()
ax4.set_title('Griswold1999')
plt.xlabel('缺失率')
plt.ylabel('RF距离')
#显示图像
plt.savefig('四个数据集缺失插补建树比较.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
data.plot()
plt.show()

# %%
data1[:1]
# Out:
# method  our  Random  Medain
# 0.05     58      80      56
# 0.10     78      82      78
# 0.20     94     110     112
# 0.30    122     120     116
# 0.40    108     138     130
# 0.50    118     138     132
